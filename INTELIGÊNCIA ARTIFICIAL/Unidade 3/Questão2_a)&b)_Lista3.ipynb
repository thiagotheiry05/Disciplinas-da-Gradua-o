# %% [markdown]
# <a href="https://colab.research.google.com/github/thiagotheiry05/Disciplinas-da-Graduacao/blob/main/INTELIG%C3%8ANCIA%20ARTIFICIAL/Unidade%203/Quest%C3%A3o2_a)%26b)_Lista3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = np.array([
    [-5.82,-4.58,-1.97],
    [-4.68 ,2.16, 3.71],
    [-4.68, 2.16 ,3.71],
    [3.36, -3.19, 1.09],
  	[7.72 ,0.88 ,1.80],
    [-7.64 ,3.06 ,3.50],
    [-6.87 ,0.57 ,-5.45],
    [4.47 ,-2.62 ,5.76],
    [7.73 ,-2.01 ,5.18],
    [-7.71 ,3.34 ,-6.33],
    [-5.91 ,-0.49 ,-5.68],
    [2.18 ,3.81 ,5.82],
    [6.72 ,-0.93 ,-3.04],
    [-5.25 ,-0.26 ,0.56],
    [-6.94 ,-1.22 ,1.13],
    [7.09 ,0.20 ,2.25],
    [6.81 ,3.17 ,-4.15],
    [-4.19 ,4.24 ,4.04],
    [-5.38 ,-1.74 ,1.43],
    [5.08 ,3.30 ,5.33],
    [7.27 ,0.93 ,-2.78]
])

# %%
x = dataset[:, 0]
y = dataset[:, 1]
z = dataset[:, 2]

plt.figure()

# subplot 1
plt.subplot(3,2,1)
plt.scatter(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.grid()

# subplot 2
plt.subplot(3,2,2)
plt.scatter(x,z)
plt.xlabel('x')
plt.ylabel('z')
plt.grid()

# subplot 3
plt.subplot(3,2,3)
plt.scatter(y,x)
plt.xlabel('y')
plt.ylabel('x')
plt.grid()

# subplot 4
plt.subplot(3,2,4)
plt.scatter(y, z)
plt.xlabel('y')
plt.ylabel('z')
plt.grid()

# subplot 3
plt.subplot(3,2,5)
plt.scatter(z, x)
plt.xlabel('z')
plt.ylabel('x')
plt.grid()

# subplot 4
plt.subplot(3,2,6)
plt.scatter(z, y)
plt.xlabel('z')
plt.ylabel('y')
plt.grid()


# Exibir a figura
plt.tight_layout()
plt.show()

# %%
x = dataset[:, 0]
y = dataset[:, 1]
z = dataset[:, 2]

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

ax.scatter(x, y, z)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %% [markdown]
# #Letra a) Considerar que a rede possui três neurônio que corresponde a existência de três clusters nos dados. Inicializar os pesos dos neurônios (centroides) de forma aleatória

# %%
num_clusters = 3
num_iterations = 100

# Inicialização aleatória dos centroides
centroids = dataset[np.random.choice(range(len(dataset)), size=num_clusters, replace=False)]

for _ in range(num_iterations):
    # Cálculo das distâncias entre os pontos e os centroides
    distances = np.linalg.norm(dataset[:, np.newaxis] - centroids, axis=-1)

    # Atribuição dos pontos aos clusters
    cluster_assignments = np.argmin(distances, axis=1)

    # Atualização dos centroides
    for i in range(num_clusters):
        centroids[i] = np.mean(dataset[cluster_assignments == i], axis=0)

# Plotagem dos pontos do dataset
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(dataset[:, 0], dataset[:, 1], dataset[:, 2], c=cluster_assignments, cmap='viridis')

# Plotagem dos centroides
ax.scatter(centroids[:, 0], centroids[:, 1], centroids[:, 2], c='red', marker='x', s=50, linewidths=2)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %% [markdown]
# # Letra b) Considerar que existam três clusters e a inicialização dos centros seja dada por m1=(0,0,0)^t, m2=(1,1,1)^t, m3=(-1,0,2)^t.

# %%
num_clusters = 3
num_iterations = 100

# Inicialização dos centroides
centroids = np.array([[0, 0, 0], [1, 1, 1], [-1, 0, 2]])

for _ in range(num_iterations):
    # Cálculo das distâncias entre os pontos e os centroides
    distances = np.linalg.norm(dataset[:, np.newaxis] - centroids, axis=-1)

    # Atribuição dos pontos aos clusters
    cluster_assignments = np.argmin(distances, axis=1)

    # Atualização dos centroides
    for i in range(num_clusters):
        centroids[i] = np.mean(dataset[cluster_assignments == i], axis=0)

# Plotagem dos pontos do dataset
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(dataset[:, 0], dataset[:, 1], dataset[:, 2], c=cluster_assignments, cmap='viridis')

# Plotagem dos centroides
ax.scatter(centroids[:, 0], centroids[:, 1], centroids[:, 2], c='red', marker='x', s=50, linewidths=2)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()
