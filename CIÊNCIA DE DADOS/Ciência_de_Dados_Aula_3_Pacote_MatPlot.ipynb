# %% [markdown]
# # Disciplina: Ciência de Dados (DCA-0131)
# Prof. Luiz Affonso Guedes
#
# ### Departamento de Engenharia de Computação e Automação - DCA
#
# UFRN - 2022
#
# *OBS: Favor fazer cópia do notebook antes de alterá-lo.

# %% [markdown]
# ## Aula 3 - Pacote de Gráficos Matplot

# %% [markdown]
# ### Pacotes para Traçar Gráficos em Python
# Há diversos pacotes gráficos em Python. Matplot é um dos mais populares.
#
# Site oficial do Matplotlib:
#
# https://matplotlib.org/index.html
#
#
# Matplotlib é uma biblioteca de visualização de dados multiplataforma construída sobre o pacote numPy, e projetada também para trabalhar com o SciPy.
#
# - Para importar o pacote matplot
#     - import matplotlib as mpl
#     - import matplotlib.pyplot as plt    --> É a interface de traçado de gráficos
#
#
# - Com Matplot é possível traçar diversas formas de gráficos. Sendo o gráfico d elinhas o mais básico. Sua forma geral é a seguinte:
#     - import matplotlib.pyplot as plt
#     - plt.plot(x,y)
#     - plt.show()

# %%
# Exemplo de uso: Estimativa da população mundial até o ano de 2100, em bilhões de pessoas
 
ano = range(1950, 2101,1)
populacao = [2.53, 2.57, 2.62, 2.67, 2.71,2.76,2.81, 2.86, 2.92,2.97,
 3.03, 3.08, 3.14, 3.2, 3.26, 3.33, 3.4, 3.47,
 3.54, 3.62, 3.69, 3.77, 3.84, 3.92, 4.0, 4.07,
 4.15, 4.22, 4.3, 4.37, 4.45, 4.53, 4.61, 4.69,
 4.78, 4.86, 4.95, 5.05, 5.14, 5.23, 5.32, 5.41,
 5.49, 5.58, 5.66, 5.74, 5.82, 5.9, 5.98, 6.05,
 6.13, 6.2, 6.28, 6.36, 6.44, 6.51, 6.59, 6.67,
 6.75, 6.83, 6.92, 7.0, 7.08, 7.16, 7.24, 7.32,
 7.4, 7.48, 7.56, 7.64, 7.72, 7.79, 7.87, 7.94,
 8.01, 8.08, 8.15, 8.22, 8.29, 8.36, 8.42, 8.49,
 8.56, 8.62, 8.68, 8.74, 8.8, 8.86, 8.92, 8.98,
 9.04, 9.09, 9.15, 9.2, 9.26, 9.31, 9.36, 9.41,
 9.46, 9.5, 9.55, 9.6, 9.64, 9.68, 9.73, 9.77,
 9.81, 9.85, 9.88, 9.92, 9.96, 9.99, 10.03, 10.06,
 10.09, 10.13, 10.16, 10.19, 10.22, 10.25, 10.28, 10.31,
 10.33, 10.36, 10.38, 10.41, 10.43, 10.46, 10.48, 10.5,
 10.52, 10.55, 10.57, 10.59, 10.61, 10.63, 10.65, 10.66,
 10.68, 10.7, 10.72, 10.73, 10.75, 10.77, 10.78, 10.79,
 10.81, 10.82, 10.83, 10.84, 10.85]

# %%
# Exemplo de uso de gráfico de linha
# Carregar o sub-pacote matplot.pyplot

import matplotlib.pyplot as plt

  
# print dos últimos elementos das listas "ano" e "populacao"
print(ano[-1])
print(populacao[-1])


# Plot de linha: ano no eixo x e populacao no eixo y
plt.xlabel("Ano")
plt.ylabel("Ppopulação em bilhões")
plt.plot(ano, populacao)

# Mostrar o gráfico
plt.show()
# Out:
# 2100
# 10.85

# %%
# Exercício: Escreva um programa que retorne o primeiro ano 
#em que se estima que a população será superior a 10 bilhoes de pessoas

for i, pop in enumerate(populacao):
    if pop > 10:
        primeiro_ano = ano[i]
        break

print("o primeiro ano a passar de 10bi é:" , primeiro_ano)
# Out:
# o primeiro ano a passar de 10bi é: 2062

# %%
ano[112]
# Out:
# 2062

# %%
# Outra Resposta do exercício
i = 0
pop1 = populacao[i]

while (pop1 < 10):
    i += 1
    pop1 = populacao[i]
    
ano[i]
# Out:
# 2062

# %%
# Outra Resposta do exercício
import numpy as np
popArray = np.array(populacao)
anoArray = np.array(ano)
l1 = len(popArray[popArray>10])
l2 = len(popArray)
l2-l1
ano[112]
# Out:
# 2062

# %% [markdown]
# ### Observação:
# Não podemos esquecer que se trata de um pacote orientado a objetos.
#
# No caso, Pylab é uma interface para o mesmo conjunto de funções, que segue a sintaxe da API de traçado de gráficos do Matlab.
#
# Pylab é um pouco mais conveniente de usar para programa de porte pequeno, enquanto que o Matplotlib dá controle mais detalhado sobre como os plots são criados.

# %%
# Exemplo: importantando todo o pacote, sem precisar referenciar objetos
# Exemplo de uso simples do comando plot()

from matplotlib.pylab import *

def f(t):
 return t**2*exp(-t**2)
t = linspace(0, 3, 31) # geração de 31 pontos linearmente espaçados entre 0 e 3
y = zeros(len(t)) # alocar lista y com mesma dimensão de t

for i in range(len(t)):
 y[i] = f(t[i])
plot(t, y)
show()

# %%
# Exemplo de uso simples do comando plot()
# Incorporação de: Título do Gráfico e dos eixos, legenda e salvar gráfico

for i in range(len(t)):
 y[i] = f(t[i])
plot(t, y)

xlabel("tempo(s)")
ylabel("y - Nível (m)")
legend(["t^2*exp(-t^2)"])
axis([0, 3, -0.05, 0.6]) # [tmin, tmax, ymin, ymax]
title("Título do Gráfico")
savefig("tmp1.pdf")  # Salvar gráfico em .pdf
show()
savefig("temp2.pdf")

# %%
# Exemplo de uso simples do comando plot()
# Incorporação o Grid no gráfico

for i in range(len(t)):
 y[i] = f(t[i])
plot(t, y)

xlabel("tempo(s)")
ylabel("y - Nível (m)")
legend(["t^2*exp(-t^2)"])
axis([0, 3, -0.05, 0.6]) # [tmin, tmax, ymin, ymax]
title("Título do Gráfico")
grid()
show()

# %%
# Exemplo de uso simples do comando plot()
# Como plotar múltiplos gráficos num mesmo plot

def f1(t):
 return t**2*exp(-t**2)
def f2(t):
 return t**2*f1(t)

t = linspace(0, 3, 51)
y1 = f1(t)
y2 = f2(t)
plot(t, y1)
#hold("on")   # Não há a necessidade 
plot(t, y2)
xlabel("tempo")
ylabel("y")
legend(["t^2*exp(-t^2)", "t^4*exp(-t^2)"])
title("Plotando duas curvas num mesmo gráfico")
show()

# %%
# Exemplo de uso simples do comando plot()
# Como plotar múltiplos gráficos num mesmo plot
# Com Especificação da cor e tipo do traçado dos gráficos

def f1(t):
 return t**2*exp(-t**2)
def f2(t):
 return t**2*f1(t)

t = linspace(0, 3, 51)
y1 = f1(t)
y2 = f2(t)
plot(t, y1, "r-")
#hold("on")   # Não há a necessidade 
plot(t, y2, "bo")
xlabel("tempo")
ylabel("y")
legend(["t^2*exp(-t^2)", "t^4*exp(-t^2)"])
title("Plotando duas curvas num mesmo gráfico")
show()

# %%
# Exemplo de uso simples do comando plot()
# Como plotar múltiplos gráficos num mesmo plot
# Utilizando apenas um comando plot

def f1(t):
 return t**2*exp(-t**2)
def f2(t):
 return t**2*f1(t)

t = linspace(0, 3, 51)
y1 = f1(t)
y2 = f2(t)
plot(t, y1, t, y2)
xlabel("tempo")
ylabel("y")
legend(["t^2*exp(-t^2)", "t^4*exp(-t^2)"])
title("Plotando duas curvas num mesmo gráfico")
show()

# %% [markdown]
# ### Exercício
# Reescreva o programa anterior, mas com grid e especificando o tipo de traçado:
# - y1 --> vermelho com linhas
# - y2 --> azul com pontos
#
# Salve o gráfico no arquivo "tmp2.pdf"

# %%
# Exercício: Plotar dos gráficos num mesmo plot 
# com especificação de cor e tipo do traçado
def f1(t):
 return t**2*exp(-t**2)
def f2(t):
 return t**2*f1(t)

t = linspace(0, 3, 51)
y1 = f1(t)
y2 = f2(t)
plot(t, y1, '-r') 
plot(t, y2, "bo")
xlabel("tempo")
ylabel("y")
legend(["t^2*exp(-t^2)", "t^4*exp(-t^2)"])
title("Plotando duas curvas num mesmo gráfico")
grid()
show()
savefig("tmp2.pdf")

# %%
# Exemplo - os gráficos podem ser salvos em diversos formatos 

import pylab
import numpy as np
x = np.arange ( -3.14 , 3.14 , 0.01)
y = np.sin(x)
# pylab.plot (x, y, label = 'função seno')

pylab.plot (x, y)
pylab.xlabel('pontos')
pylab.ylabel('curva')
pylab.legend(['função seno'])

# pylab.savefig ("myplot.png") # salvar em formato png
# pylab.savefig ("myplot.eps") # salvar em formato eps
# pylab.savefig ("myplot.pdf") # salvar em formato pdf

# %%
! ls
# Out:
# myplot.eps  myplot.pdf	myplot.png  sample_data  temp2.pdf  tmp1.pdf  tmp2.pdf

# %%
# Exemplo
import numpy as np # 
import matplotlib.pyplot as plt # 
x = np. arange ( -3.14 , 4*3.14 , 0.01) # criação do array x
y1 = np.sin(x) 
plt. plot (x, y1) 
plt. show ()

# %% [markdown]
# ### Exercício:
#
# Baseando-se no exemplo acima, escreva uma programa que num mesmo plot trace os seguintes gráficos:
# - $y1 = sin(x) + 1$
# - $y2 = 1.5*cos(x) - .5$
# - $y3 = max(y1,y2)$
# - $y4 = mim(y1,y2)$
#
# Escolha as cores e formato dos gráficos, com grid e salve a figura no arquivo "tmp3.pdf"

# %%
# Exercício:

import numpy as np # já está importado
import matplotlib.pyplot as plt # já está importado

x = np.arange ( -3.14 , 4*3.14 , 0.01) # criação do array x
y1 = np.sin(x) + 1
y2 = (1.5*np.cos(x)) - .5
y3 = np.maximum(y1, y2)
y4 = np.minimum(y1, y2)
plt.plot(x, y1,'-b', label='y1')
plt.plot(x, y2,'-g', label='y2') 
plt.plot(x, y3,'-r',linestyle='--', label='y3') 
plt.plot(x, y4,'-y', linestyle='--', label='y4') 
plt.grid()
plt.legend()
plt.show()
savefig("tmp3.pdf")
# Out:
# <ipython-input-68-aab70bf77533>:13: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-r" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(x, y3,'-r',linestyle='--', label='y3')
# <ipython-input-68-aab70bf77533>:14: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-y" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(x, y4,'-y', linestyle='--', label='y4')

# %%
# Exemplo de definição de cor das curvas nos gráficos
import numpy as np
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x - 0), color='blue') # especificação da cor pelo nome
plt.plot(x, np.sin(x - 1), color='g') # especificação por código (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75') # escala de cinza entre 0 e 1
plt.plot(x, np.sin(x - 3), color='#FFDD44') # Hex code (RRGGBB de 00 até FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, valures entre 0 e 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # todas cores suportadas em HTML

# %%
# Exemplo de definição de estilo das curvas nos gráficos
import numpy as np
x = np.linspace(0, 10, 100)

plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

# Especificação usando a forma em código:
plt.plot(x, x + 10, linestyle='-') # solid
plt.plot(x, x + 11, linestyle='--') # dashed
plt.plot(x, x + 12, linestyle='-.') # dashdot
plt.plot(x, x + 13, linestyle=':'); # dotted

# %%
# Exemplo de definição de cor e estilo das curvas nos gráficos
import numpy as np
x = np.linspace(0, 10, 100)

plt.plot(x, x + 0, '-g') # solid green
plt.plot(x, x + 1, '--c') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r'); # dotted red

# %%
# Exemplo de definição de cor e estilo das curvas nos gráficos
plt.plot(x, np.sin(x), '-ok');

# %%
# Exemplo - Determinando limite de um gráfico
plt.plot(x, np.sin(x))
plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5);

# %%
# Exemplo - Determinando limite de um gráfico
plt.plot(x, np.sin(x))
plt.xlim(10, 0)
plt.ylim(1.2, -1.2);

# %%
# Exemplo - Determinando limite de um gráfico
# Método plt.axis([xmin, xmax, ymin,ymax])
plt.plot(x, np.sin(x))
plt.grid()
plt.axis([-1, 11, -1.5, 1.5]);

# %%
# Exemplo - Determinando limite de um gráfico
plt.plot(x, np.sin(x))
plt.axis('tight'); # indica que se deseja utilizar 100% do gráfico

# %%
# Exemplo - Outro modo de definir a legenda do gráfico
import numpy as np
x = np.linspace(0, 10, 100)

plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.legend();

# %% [markdown]
# ### Observação:
# Para se plotar mais de um gráfico, precisamos definir o conceito de figura.
# - Numa figura é possível se definir diversos subplots.
#    - criação da figura  --> figure(num_figura)
#    - criação do subplot --> subplot(num_linha, num_coluna, num_grafico)

# %%
# Exemplo de subplots
# Plotando mais de um plot numa mesma figura

figure() # criação da figura

subplot(2, 1, 1)

t = linspace(0, 3, 51)
y1 = f1(t)
y2 = f2(t)
t3 = t[::4]
y3 = f2(t3)

#  ------ definição do subplot 1   -----------
subplot(2, 1, 1)
plot(t, y1, "r-", t, y2, "bo")
xlabel("t")
ylabel("y1")
axis([t[0], t[-1], min(y2)-0.05, max(y2)+0.5])
legend(["t^2*exp(-t^2)", "t^4*exp(-t^2)"])
title("Título do sub_plot1")


#  ------ definição do subplot 2   -----------
subplot(2, 1, 2)
plot(t, y1, "b-", t3, y3, "ys")
xlabel("t")
ylabel("y2")
axis([0, 4, -0.2, 0.6])
legend(["t^2*exp(-t^2)", "t^4*exp(-t^2)"])
show()

# %%
# Exemplo de subplots
# Plotando mais de um plot numa mesma figura


print("------------------------------------------------------------")
print("Verifique o que mudou neste programa com relação ao anterior")
print("------------------------------------------------------------")

figure() # criação da figura - no caso não se especificou o número da figura

subplot(2, 1, 1)

t = linspace(0, 3, 51)
y1 = f1(t)
y2 = f2(t)
t3 = t[::4]
y3 = f2(t3)

#  ------ definição do subplot 1   -----------
subplot(2, 2, 3)
plot(t, y1, "r-", t, y2, "bo")
xlabel("t")
ylabel("y1")
axis([t[0], t[-1], min(y2)-0.05, max(y2)+0.5])
legend(["t^2*exp(-t^2)", "t^4*exp(-t^2)"])
title("Título do sub_plot1")


#  ------ definição do subplot 2   -----------
subplot(2, 2, 4)
plot(t, y1, "b-", t3, y3, "ys")
xlabel("t")
ylabel("y2")
axis([0, 4, -0.2, 0.6])
legend(["t^2*exp(-t^2)", "t^4*exp(-t^2)"])

show()
# Out:
# ------------------------------------------------------------
# Verifique o que mudou neste programa com relação ao anterior
# ------------------------------------------------------------

# %% [markdown]
# ### Exercício
# Reescreva o programa anterior, com:
# - 03 subplots, sendo 02 em cima e 01 em baixo
# - inclua grid no subplot de baixo
# - salve a figura no arquivo "tmp4.pdf"

# %%
# Exercício: Programa com vários sub-plots

figure() # criação da figura - no caso não se especificou o número da figura

subplot(2, 2, 1)

t = linspace(0, 3, 51)
y1 = f1(t)
y2 = f2(t)
t3 = t[::4]
y3 = f2(t3)

#  ------ definição do subplot 1   -----------
subplot(2, 2, 1)
plot(t, y1, "r-", t, y2, "bo")
xlabel("t")
ylabel("y1")
axis([t[0], t[-1], min(y2)-0.05, max(y2)+0.5])
legend(["t^2*exp(-t^2)", "t^4*exp(-t^2)"])
title("Título do sub_plot1")


#  ------ definição do subplot 2   -----------
subplot(2, 2, 2)
plot(t, y1, "b-", t3, y3, "ys")
xlabel("t")
ylabel("y2")
axis([0, 4, -0.2, 0.6])
legend(["t^2*exp(-t^2)", "t^4*exp(-t^2)"])

#  ------ definição do subplot 3   -----------
subplot(2, 2, 3)
grid()
show()

# %%
# Exemplo de subplots
# Escrevendo texto (string) num plot

for i in range(1, 7):
 plt.subplot(2, 3, i)
 plt.text(0.5, 0.5, str((2, 3, i)),
          fontsize=18, ha='center')

# %%
# Exemplo de gráficos superpostos

from pylab import *
x = linspace(0, 5, 10)
y = x ** 2

fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # axes da figura principal
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # inset axes - figura secundária

# Figura Principal
axes1.plot(x, y, 'r')
axes1.set_xlabel('x')
axes1.set_ylabel('y')
axes1.set_title('Título Principal')

# Segunda Figura
axes2.plot(x, y, 'g')
axes2.set_xlabel('y')
axes2.set_ylabel('x')
axes2.set_title('Título da segunda figura');

# %% [markdown]
# ### Exercício:
# No programa a seguir, varie os parâmetros dos gráficos e infira o que eles significam.

# %%
# Exemplo de gráficos superpostos

from pylab import *
x = linspace(0, 5, 10)
y = x ** 2

#  ------  Parâmetros dos gráficos   -------------

# dimensao da imagem 1
baseX1 = 0.1
baseY1 = 0.1
dX1 = 0.8
dY1 = 0.8

# dimensao da imagem 2
baseX2 = 0.2
baseY2 = 0.5
dX2 = 0.4
dY2 = 0.3

# Dando a dimensão das figuras com bases nos parametros passados anteriormente
fig = plt.figure()
axes1 = fig.add_axes([baseX1, baseY1, dX1, dY1]) # axes da figura principal
axes2 = fig.add_axes([baseX2, baseY2, dX2, dY2]) # axes da figura secundária

# Figura Principal
axes1.plot(x,y, 'r')
axes1.set_xlabel('x')
axes1.set_ylabel('y')
axes1.set_title('Título Principal')

# Segunda Figura
axes2.plot(y, x, 'g')
axes2.set_xlabel('y')
axes2.set_ylabel('x')
axes2.set_title('Título da segunda figura');

# %%
# Exemplo: Uso de mais de uma figura

import pylab
pylab.figure(1)
pylab.plot( range (10) , 'ro')
pylab.figure(2)
pylab.plot ( range (100) , 'x')

# %% [markdown]
# ### Usando Estilos Tipo Matlab e Orientado-a-Objetos
# - Hieraquia de figuras, eixos, gráficos
# - simplicidade x flexibilidade
# - Como se pode mudificar uma figura e ou um eixo, quando se há vários deles?

# %%
# Exemplo: Sub-plots com Estilo Matlab
import numpy as np
x = np.linspace(0, 10, 100)

plt.figure() # criar uma figura

# criação do primeiro de dois paineis and configurar o eixo (sub-plot)
plt.subplot(2, 1, 1) # (linhas, colunas, número do painel)
plt.plot(x, np.sin(x))

# criação do segundo painel e configuração do eixo (sub-plot)
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x));

# %%
# Exemplo: Sub-plots com Estilo Orientado-a-Objetos

# Primeiro, cria-se um estrutura em grade de plots

# ax será um array de dois objetos eixos (objetos sub-plot)
# fig será a figura
fig, ax = plt.subplots(2)

# Chamada do método plot() sobre os objetos eixos (plot) específicos
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x));

# %%
# Exemplo: Sub-plots com Estilo Orientado-a-Objetos

# Primeiro, cria-se um estrutura em grade de plots

# ax será um array de dois objetos eixos (objetos sub-plot)
# fig será a figura
#fig, ax = plt.subplots(2)
fig, ax = plt.subplots(2,2)

# Chamada do método plot() sobre os objetos eixos (plot) específicos
ax[0][0].plot(x, np.sin(x))
ax[1][1].plot(x, np.cos(x));
ax[1][0].plot(x, np.cos(x)+3);

# %%
# Exemplo: Sub-plots com Estilo Orientado-a-Objetos

# Primeiro, cria-se um estrutura em grade de plots

# ax será um array de dois objetos eixos (objetos sub-plot)
# fig será a figura
fig, ax = plt.subplots(2,2)

# Chamada do método plot() sobre os objetos eixos (plot) específicos
ax[0,0].plot(x, np.sin(x))
ax[1,1].plot(x, np.cos(x));

# %%
# Exemplo: Retorno de figura e eixos - Estilo Clássico
#plt.style.use('classic')
fig = plt.figure()
ax = plt.axes()

# %%
# Exemplo: Retorno de figura e eixos - Estilo Seaborn
plt.style.use('seaborn-whitegrid')
fig = plt.figure()
ax = plt.axes()
# Out:
# <ipython-input-99-431cf93f5460>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
# Exemplo - Estilo Orientado-a-Objetos
# plot é método do objeto eixo (axes - gráfico) - plt
# 
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));

# plt.plot(x, np.sin(x)); Usando a interface pylab - Estilo Matlab

# %% [markdown]
# ### Observação:
# Nem todos os métodos do estilo Matlab têm correspondências para Orientação-a-Objetos.
#
# A seguir são apresentados alguns exemplos de métodos equivalentes nos dois estilos:
#
#
# • plt.xlabel() → ax.set_xlabel()
#
# • plt.ylabel() → ax.set_ylabel()
#
# • plt.xlim() → ax.set_xlim()
#
# • plt.ylim() → ax.set_ylim()
#
# • plt.title() → ax.set_title()

# %% [markdown]
# #### A seguir temos um exemplo de como plotar duas curvas num mesmo plot, com cada uma tendo a sua própria escala.

# %%
# Exemplo - Uso de duas escalas num mesmo plot - exemplo vindo do site do matplotlib
import numpy as np
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots()
t = np.arange(0.01, 10.0, 0.01)
s1 = np.exp(t)
ax1.plot(t, s1, 'b-')
ax1.set_xlabel('time (s)')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('exp', color='b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
s2 = np.sin(2 * np.pi * t)
ax2.plot(t, s2, 'r.')
ax2.set_ylabel('sin', color='r')
ax2.tick_params('y', colors='r')

fig.tight_layout()
plt.show()

# %%
# Exemplo - Estilo Orientado-a-Objetos

ax = plt.axes()
ax.plot(x, np.sin(x))
ax.set(xlim=(0, 10), ylim=(-2, 2), 
       xlabel='x', ylabel='sin(x)',
       title='A Simple Plot');

# %% [markdown]
# ### Observação:
# Para se rodar os próximos exemplos será necessário executar as células abaixo, para carregar as seguinte veriáveis:
#
#     - life_exp, que contém os valores da expectativa de vida para uma lista de países.
#     - gdp_cap, que contém os valores do PIB per capita para cada país, dado em US Dollars.

# %%
# Expectativa de vida em 2007 para vários países

life_exp = [43.828000000000003,
 76.423000000000002,
 72.301000000000002,
 42.731000000000002,
 75.319999999999993,
 81.234999999999999,
 79.828999999999994,
 75.635000000000005,
 64.061999999999998,
 79.441000000000003,
 56.728000000000002,
 65.554000000000002,
 74.852000000000004,
 50.728000000000002,
 72.390000000000001,
 73.004999999999995,
 52.295000000000002,
 49.579999999999998,
 59.722999999999999,
 50.43,
 80.653000000000006,
 44.741000000000007,
 50.651000000000003,
 78.552999999999997,
 72.960999999999999,
 72.888999999999996,
 65.152000000000001,
 46.462000000000003,
 55.322000000000003,
 78.781999999999996,
 48.328000000000003,
 75.748000000000005,
 78.272999999999996,
 76.486000000000004,
 78.331999999999994,
 54.790999999999997,
 72.234999999999999,
 74.994,
 71.338000000000022,
 71.878,
 51.578999999999994,
 58.039999999999999,
 52.947000000000003,
 79.313000000000002,
 80.656999999999996,
 56.734999999999999,
 59.448,
 79.406000000000006,
 60.021999999999998,
 79.483000000000004,
 70.259,
 56.006999999999998,
 46.388000000000012,
 60.915999999999997,
 70.198000000000008,
 82.207999999999998,
 73.338000000000022,
 81.757000000000005,
 64.698000000000008,
 70.650000000000006,
 70.963999999999999,
 59.545000000000002,
 78.885000000000005,
 80.745000000000005,
 80.546000000000006,
 72.566999999999993,
 82.602999999999994,
 72.534999999999997,
 54.109999999999999,
 67.296999999999997,
 78.623000000000005,
 77.588000000000022,
 71.992999999999995,
 42.591999999999999,
 45.677999999999997,
 73.951999999999998,
 59.443000000000012,
 48.302999999999997,
 74.241,
 54.466999999999999,
 64.164000000000001,
 72.801000000000002,
 76.194999999999993,
 66.802999999999997,
 74.543000000000006,
 71.164000000000001,
 42.082000000000001,
 62.069000000000003,
 52.906000000000013,
 63.784999999999997,
 79.762,
 80.203999999999994,
 72.899000000000001,
 56.866999999999997,
 46.859000000000002,
 80.195999999999998,
 75.640000000000001,
 65.483000000000004,
 75.536999999999978,
 71.751999999999995,
 71.421000000000006,
 71.688000000000002,
 75.563000000000002,
 78.097999999999999,
 78.746000000000024,
 76.441999999999993,
 72.475999999999999,
 46.241999999999997,
 65.528000000000006,
 72.777000000000001,
 63.061999999999998,
 74.001999999999995,
 42.568000000000012,
 79.971999999999994,
 74.662999999999997,
 77.926000000000002,
 48.158999999999999,
 49.338999999999999,
 80.941000000000003,
 72.396000000000001,
 58.555999999999997,
 39.613,
 80.884,
 81.701000000000022,
 74.143000000000001,
 78.400000000000006,
 52.517000000000003,
 70.616,
 58.420000000000002,
 69.819000000000003,
 73.923000000000002,
 71.777000000000001,
 51.542000000000002,
 79.424999999999997,
 78.242000000000004,
 76.384,
 73.747,
 74.248999999999995,
 73.421999999999997,
 62.698,
 42.383999999999993,
 43.487000000000002]

# %%
# Expectativa de vida em 1950 para vários países
life_exp1950 = [28.8,
 55.23,
 43.08,
 30.02,
 62.48,
 69.12,
 66.8,
 50.94,
 37.48,
 68.0,
 38.22,
 40.41,
 53.82,
 47.62,
 50.92,
 59.6,
 31.98,
 39.03,
 39.42,
 38.52,
 68.75,
 35.46,
 38.09,
 54.74,
 44.0,
 50.64,
 40.72,
 39.14,
 42.11,
 57.21,
 40.48,
 61.21,
 59.42,
 66.87,
 70.78,
 34.81,
 45.93,
 48.36,
 41.89,
 45.26,
 34.48,
 35.93,
 34.08,
 66.55,
 67.41,
 37.0,
 30.0,
 67.5,
 43.15,
 65.86,
 42.02,
 33.61,
 32.5,
 37.58,
 41.91,
 60.96,
 64.03,
 72.49,
 37.37,
 37.47,
 44.87,
 45.32,
 66.91,
 65.39,
 65.94,
 58.53,
 63.03,
 43.16,
 42.27,
 50.06,
 47.45,
 55.56,
 55.93,
 42.14,
 38.48,
 42.72,
 36.68,
 36.26,
 48.46,
 33.68,
 40.54,
 50.99,
 50.79,
 42.24,
 59.16,
 42.87,
 31.29,
 36.32,
 41.72,
 36.16,
 72.13,
 69.39,
 42.31,
 37.44,
 36.32,
 72.67,
 37.58,
 43.44,
 55.19,
 62.65,
 43.9,
 47.75,
 61.31,
 59.82,
 64.28,
 52.72,
 61.05,
 40.0,
 46.47,
 39.88,
 37.28,
 58.0,
 30.33,
 60.4,
 64.36,
 65.57,
 32.98,
 45.01,
 64.94,
 57.59,
 38.64,
 41.41,
 71.86,
 69.62,
 45.88,
 58.5,
 41.22,
 50.85,
 38.6,
 59.1,
 44.6,
 43.58,
 39.98,
 69.18,
 68.44,
 66.07,
 55.09,
 40.41,
 43.16,
 32.55,
 42.04,
 48.45]

# %%
# PIB per capta em 2007 para vários países
gdp_cap = [974.58033839999996,
 5937.0295259999984,
 6223.3674650000003,
 4797.2312670000001,
 12779.379639999999,
 34435.367439999995,
 36126.492700000003,
 29796.048340000001,
 1391.253792,
 33692.605080000001,
 1441.2848730000001,
 3822.137084,
 7446.2988029999997,
 12569.851769999999,
 9065.8008250000003,
 10680.792820000001,
 1217.0329939999999,
 430.07069159999998,
 1713.7786860000001,
 2042.0952400000001,
 36319.235009999997,
 706.01653699999997,
 1704.0637240000001,
 13171.638849999999,
 4959.1148540000004,
 7006.5804189999999,
 986.14787920000003,
 277.55185870000003,
 3632.5577979999998,
 9645.06142,
 1544.7501119999999,
 14619.222719999998,
 8948.1029230000004,
 22833.308509999999,
 35278.418740000001,
 2082.4815670000007,
 6025.3747520000015,
 6873.2623260000009,
 5581.1809979999998,
 5728.3535140000004,
 12154.089749999999,
 641.36952360000021,
 690.80557590000001,
 33207.0844,
 30470.0167,
 13206.48452,
 752.74972649999995,
 32170.37442,
 1327.6089099999999,
 27538.41188,
 5186.0500030000003,
 942.6542111,
 579.23174299999982,
 1201.637154,
 3548.3308460000007,
 39724.978669999997,
 18008.944439999999,
 36180.789190000003,
 2452.210407,
 3540.6515639999998,
 11605.71449,
 4471.0619059999999,
 40675.996350000001,
 25523.277099999999,
 28569.719700000001,
 7320.8802620000015,
 31656.068060000001,
 4519.4611709999999,
 1463.249282,
 1593.06548,
 23348.139730000006,
 47306.989780000004,
 10461.05868,
 1569.3314419999999,
 414.5073415,
 12057.49928,
 1044.7701259999999,
 759.34991009999999,
 12451.6558,
 1042.581557,
 1803.151496,
 10956.991120000001,
 11977.57496,
 3095.7722710000007,
 9253.896111,
 3820.1752299999998,
 823.68562050000003,
 944.0,
 4811.0604290000001,
 1091.359778,
 36797.933319999996,
 25185.009109999999,
 2749.3209649999999,
 619.67689239999982,
 2013.9773049999999,
 49357.190170000002,
 22316.192869999999,
 2605.94758,
 9809.1856360000002,
 4172.8384640000004,
 7408.9055609999996,
 3190.4810160000002,
 15389.924680000002,
 20509.64777,
 19328.709009999999,
 7670.122558,
 10808.47561,
 863.08846390000019,
 1598.4350890000001,
 21654.83194,
 1712.4721360000001,
 9786.5347139999994,
 862.54075610000018,
 47143.179640000002,
 18678.314350000001,
 25768.257590000001,
 926.14106830000003,
 9269.6578079999999,
 28821.063699999999,
 3970.0954069999998,
 2602.3949950000001,
 4513.4806429999999,
 33859.748350000002,
 37506.419070000004,
 4184.5480889999999,
 28718.276839999999,
 1107.482182,
 7458.3963269999977,
 882.9699437999999,
 18008.509239999999,
 7092.9230250000001,
 8458.2763840000007,
 1056.3801209999999,
 33203.261279999999,
 42951.65309,
 10611.46299,
 11415.805689999999,
 2441.5764039999999,
 3025.3497980000002,
 2280.769906,
 1271.211593,
 469.70929810000007]

# %%
# População em 2007 de diversos países

pop = [31.889923,
 3.6005229999999999,
 33.333216,
 12.420476000000001,
 40.301926999999999,
 20.434176000000001,
 8.199783,
 0.70857300000000001,
 150.448339,
 10.392226000000001,
 8.0783140000000007,
 9.1191519999999997,
 4.5521979999999997,
 1.6391309999999999,
 190.01064700000001,
 7.3228580000000001,
 14.326203,
 8.3905049999999992,
 14.131857999999999,
 17.696293000000001,
 33.390141,
 4.3690379999999998,
 10.238807,
 16.284741,
 1318.683096,
 44.227550000000001,
 0.71096000000000004,
 64.606758999999997,
 3.8006099999999998,
 4.1338840000000001,
 18.013408999999999,
 4.4933120000000004,
 11.416987000000001,
 10.228744000000001,
 5.4681199999999999,
 0.49637399999999998,
 9.3196220000000007,
 13.75568,
 80.264543000000003,
 6.9396880000000003,
 0.55120100000000005,
 4.9065849999999998,
 76.511887000000002,
 5.2384599999999999,
 61.083916000000002,
 1.4548669999999999,
 1.6883589999999999,
 82.400996000000006,
 22.873338,
 10.706289999999999,
 12.572927999999999,
 9.9478139999999993,
 1.4720409999999999,
 8.5028140000000008,
 7.4837629999999997,
 6.9804120000000003,
 9.9561080000000004,
 0.301931,
 1110.3963309999999,
 223.547,
 69.453569999999999,
 27.499638000000001,
 4.1090859999999996,
 6.426679,
 58.147733000000002,
 2.780132,
 127.467972,
 6.0531930000000003,
 35.610177,
 23.301725000000001,
 49.044789999999999,
 2.5055589999999999,
 3.921278,
 2.0126490000000001,
 3.1939419999999998,
 6.0369140000000003,
 19.167653999999999,
 13.327078999999999,
 24.821286000000001,
 12.031795000000001,
 3.2700650000000002,
 1.250882,
 108.700891,
 2.8741270000000001,
 0.68473600000000001,
 33.757174999999997,
 19.951656,
 47.761980000000001,
 2.0550799999999998,
 28.901789999999998,
 16.570613000000002,
 4.1157709999999996,
 5.6753559999999998,
 12.894864999999999,
 135.03116399999999,
 4.6279260000000004,
 3.2048969999999999,
 169.27061699999999,
 3.2421730000000002,
 6.6671469999999999,
 28.674757,
 91.077286999999998,
 38.518241000000003,
 10.642836000000001,
 3.942491,
 0.79809399999999997,
 22.276056000000001,
 8.8605879999999999,
 0.19957900000000001,
 27.601037999999999,
 12.267493,
 10.150264999999999,
 6.1445619999999996,
 4.5530090000000003,
 5.4475020000000001,
 2.0092449999999999,
 9.1187729999999991,
 43.997827999999998,
 40.448191000000001,
 20.378239000000001,
 42.292929000000001,
 1.1330659999999999,
 9.0310880000000004,
 7.5546610000000003,
 19.314747000000001,
 23.174294,
 38.13964,
 65.068149000000005,
 5.7015789999999997,
 1.056608,
 10.276158000000001,
 71.158647000000002,
 29.170397999999999,
 60.776237999999999,
 301.13994700000001,
 3.4474960000000001,
 26.084662000000002,
 85.262355999999997,
 4.018332,
 22.211742999999998,
 11.746034999999999,
 12.311143]

# %% [markdown]
# ### Gráficos tipo Histogramas:
# Para se plotar esse tipo d egráfigo se utiliza o método plt.hist(array)

# %%
# Histograma da variável life_exp
plt.hist(life_exp)

# Mostrar histograma
plt.show()

# %% [markdown]
# ### Observação:
# No exemplo anterior, não houve especificação do número de caixas (bins). Por padrão, o Mathplot define o número de caixas igual a 10. O número de caixas é bastante importante. Poucos compartimentos simplificarão a realidade e não mostrarão os detalhes. Muitas caixas superam a realidade e não mostrarão a imagem adequadamente.
#
# Para controlar o número de compartimentos para dividir seus dados, você pode definir o argumento das caixas (bins).

# %%
# Histograma de life_exp, com 15 bins (raias, caixas)

plt.hist(life_exp, bins=15)

# Mostra e limpa o plot
plt.show()
plt.clf()

# Histograma do life_exp1950, com 15 bins (raias)
plt.hist(life_exp1950, bins=15)

# Mostra e limpa o plot
plt.show()
plt.clf()

# %%
# Histograma com 5 bins
plt.hist(life_exp,bins=5)
import time
# Mostrar e limpar o plot
plt.show()
time.sleep(2)
plt.clf()

# Histograma com 20 bins

plt.hist(life_exp,bins=20)

# Mostrar e limpar o plot
plt.show()
plt.clf()

# %%
# Exemplo de histograma com uso de parâmetros defaults

import numpy as np
import matplotlib.pyplot as plt

plt.style.use('seaborn-white')
data = np.random.randn(1000)

plt.hist(data);
# Out:
# <ipython-input-23-36187e58cb3c>:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')

# %%
# Exemplo de histograma com configuração de parâmetros

plt.hist(data, bins=30,histtype='stepfilled', color='steelblue', orientation='horizontal')

#plt.hist(data, bins=None, range=None, density=False, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, stacked=False, *, data=None, **kwargs)
# Out:
# (array([ 5.,  1.,  8., 10., 15., 16., 28., 54., 50., 62., 50., 81., 77.,
#         93., 71., 78., 64., 55., 56., 38., 18., 26., 20.,  8.,  5.,  5.,
#          1.,  3.,  1.,  1.]),
#  array([-2.71022845, -2.50807164, -2.30591483, -2.10375802, -1.9016012 ,
#         -1.69944439, -1.49728758, -1.29513077, -1.09297396, -0.89081715,
#         -0.68866034, -0.48650353, -0.28434672, -0.08218991,  0.11996691,
#          0.32212372,  0.52428053,  0.72643734,  0.92859415,  1.13075096,
#          1.33290777,  1.53506458,  1.73722139,  1.93937821,  2.14153502,
#          2.34369183,  2.54584864,  2.74800545,  2.95016226,  3.15231907,
#          3.35447588]),
#  [<matplotlib.patches.Polygon at 0x7f8c62460160>])

# %%
# Exemplo de vários histogramas num mesmo gráfico

x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)
histograma_parametros = dict(histtype='stepfilled', density=True, bins=40)

plt.hist(x1, **histograma_parametros)
plt.hist(x2, **histograma_parametros)
plt.hist(x3, **histograma_parametros);

#plt.hist(x1)
#plt.hist(x2)
#plt.hist(x3)

#plt.hist(x1,x2,x3)

plt.show()

# %% [markdown]
# ### Observação:
# Em muitos casos é importante mostrar histogramas e gráficos superpostos num mesmo plot.
#
# A seguir é apresentado uma exemplo de uso de histograma e gráfico num memso plot.

# %%
# Exemplo: Histograma com plot

import numpy as np
from scipy.stats import norm   # importando do pacote SciPy
import matplotlib.pyplot as plt

# criação dos dados
mu , sigma = 100 , 15
x = mu + sigma * np.random.randn(10000)

# histograma dos dados
n, bins , patches = plt.hist(x, 50, density = True,facecolor ='green', alpha =0.75)

# Labels dos eixos
plt. xlabel ('QI ')
plt. ylabel (' Probabilidade ')

#Pode-se utilizar um string em código Latex para labels e titles :
plt.title (r'$\ mathrm { Histograma \ de\ IQ :}\ \mu =100 ,\ \ sigma =15$')
plt.axis ([40 , 160 , 0, 0.03])
plt.grid ( True )

# Curva contínua no estilo de linhas
y= norm.pdf(bins , mu , sigma)
l = plt.plot(bins , y, 'r--', linewidth =1)

# salvar a figura em arquivo
plt.savefig("histograma_com_plot.pdf")
# Mostrar a figura
plt.show()

# %% [markdown]
# ### Gráficos em pontos
#
# Em muitos casos os pontos, par(x,y), não estão dispostos em uma sequência. Então, não faz sentido utilizar o plt.plot().
#  - O método plt.plot() assumi que os ponto possui sequência lógica
#
# Para os casos onde os pontos não seguem sequências (pontos "soltos"), devemos utilizar o método plt.scatter(x,y) ao invés do plt.plot(x,y), que corresponde a gráficos de dispoersão.
#
# - import matplotlib.pyplot as plt
# - plt.scatter(x,y)
# - plt.show()

# %%
# Exemplo - Gráfico com SCATTER
# O gráfico corresponde a ponto sem lógica de sequência
# Neste caso, poderíamos utilizar o plt.plot()
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.scatter(x, y, marker='o');

# %%
# Nesse gráfico teria sentido se utilizar plt.plot() ao invés de plt.scatter()

#import matplotlib.pyplot as plt
import matplotlib.pylab as plt

plt.scatter(gdp_cap, life_exp)

# Configurar o x-axis na escala logarítmica
plt.xscale('log')

# Mostrar plot
plt.show()

# %% [markdown]
# ### Pergunta:
# No exercício anterior, você viu que o maior PIB geralmente corresponde a uma maior expectativa de vida. Em outras palavras, há uma correlação positiva.
#
# Você acha que existe uma relação entre a população e a expectativa de vida de um país?
# - A lista life_exp já está disponível.
# - A lista pop já está disponível, que corresponde às populações dos países em 2007. As populações estão em milhões de pessoas.

# %%
# Import package Matplot
import matplotlib.pyplot as plt

# Build Scatter plot
plt.scatter(pop, life_exp)

# Show plot
plt.show()

# %% [markdown]
# Adicionar títulos e labels em SCATTER é realizado de modo similar ao PLOT

# %%
# Gráfico do tipo scatter, em escala logarítmica
# com adição de título e labels

plt.scatter(gdp_cap, life_exp)
plt.xscale('log') 

# Título e labels
xlab = 'PIB per Capita [em USD]'
ylab = 'Expectativa de Vida [em anos]'
title = 'Desenvolvimento Global em in 2007'

# Adicionar labels dos eixos
plt.xlabel(xlab)
plt.ylabel(ylab)

# Adicionar título
plt.title(title)

# Mostrar plot 
plt.show()

# %% [markdown]
# Como no PLOT, aqui também é possível redefinir os labels dos eixos x e y, via os métodos plt.xticks(.,.) e plt.yticks(.,.), respectivamente.
# - plt.yticks([0,1,2], ["um","dois","tres"]), substitui os nnúmeros 0, 1 e 2 pelas strings "um", "dois" e "tres", respectivamente.

# %%
# Exemplo de uso de Scatter plot
# Redifinir o label do eixo x


plt.scatter(gdp_cap, life_exp)

# Customizações
plt.xscale('log') 
plt.xlabel('PIB per Capita [em USD]')
plt.ylabel('Expectativa de Vida [em anos]')
plt.title('Desenvolvimento Global em 2007')

# Definições dos tick_val e tick_lab
tick_val = [1000,10000,100000]
tick_lab = ['1k','10k','100k']

# Adaptar os ticks no x-axis
plt.xticks(tick_val, tick_lab)

# Mostrar o plot
plt.show()

# %% [markdown]
# Até aqui, o gráfico de dispersão (scatter) é apenas uma nuvem de pontos azuis, indistinguíveis uns dos outros.
#
# Para melhorar a visualização dos dados bom se o tamanho dos pontos corresponde à população, por exemplo.
#
# Para realizar isso, precisamos passa via variável 's' no método plt.scatter(). Essa variável é uma contendo os tamanhos de cada ponto.

# %%
# Exemplo definindo o tamanho dos pontos no método plt.scatter()

# Import numpy as np
import numpy as np

# Transformar a lista em Array: np_pop
np_pop = np.array(pop)

# Duplicar o valor de  np_pop
np_pop = np_pop * 2

# Atualização: configurar a variável s para np_pop
plt.scatter(gdp_cap, life_exp, s = np_pop)

# Customizações
plt.xscale('log') 
plt.xlabel('PIB per Capita [em USD]')
plt.ylabel('Expectativa de Vida [em anos]')
plt.title('Desenvolvimento Global em 2007')
plt.xticks([1000, 10000, 100000],['1k', '10k', '100k'])

# Mostar o plot
plt.show()

# %% [markdown]
# ### Cor nos Gráficos Tipo Scatter
# Agora vamos associar cores aos países. Para isto vamos utilizar o tipo 'dictionary'.

# %% [markdown]
# dict = {
#     'Asia':'red',
#
#     'Europe':'green',
#
#     'Africa':'blue',
#
#     'Americas':'yellow',
#
#     'Oceania':'black'
#
# }

# %%
# Lista das cores associadas aos paises
col = ['red',
 'green',
 'blue',
 'blue',
 'yellow',
 'black',
 'green',
 'red',
 'red',
 'green',
 'blue',
 'yellow',
 'green',
 'blue',
 'yellow',
 'green',
 'blue',
 'blue',
 'red',
 'blue',
 'yellow',
 'blue',
 'blue',
 'yellow',
 'red',
 'yellow',
 'blue',
 'blue',
 'blue',
 'yellow',
 'blue',
 'green',
 'yellow',
 'green',
 'green',
 'blue',
 'yellow',
 'yellow',
 'blue',
 'yellow',
 'blue',
 'blue',
 'blue',
 'green',
 'green',
 'blue',
 'blue',
 'green',
 'blue',
 'green',
 'yellow',
 'blue',
 'blue',
 'yellow',
 'yellow',
 'red',
 'green',
 'green',
 'red',
 'red',
 'red',
 'red',
 'green',
 'red',
 'green',
 'yellow',
 'red',
 'red',
 'blue',
 'red',
 'red',
 'red',
 'red',
 'blue',
 'blue',
 'blue',
 'blue',
 'blue',
 'red',
 'blue',
 'blue',
 'blue',
 'yellow',
 'red',
 'green',
 'blue',
 'blue',
 'red',
 'blue',
 'red',
 'green',
 'black',
 'yellow',
 'blue',
 'blue',
 'green',
 'red',
 'red',
 'yellow',
 'yellow',
 'yellow',
 'red',
 'green',
 'green',
 'yellow',
 'blue',
 'green',
 'blue',
 'blue',
 'red',
 'blue',
 'green',
 'blue',
 'red',
 'green',
 'green',
 'blue',
 'blue',
 'green',
 'red',
 'blue',
 'blue',
 'green',
 'green',
 'red',
 'red',
 'blue',
 'red',
 'blue',
 'yellow',
 'blue',
 'green',
 'blue',
 'green',
 'yellow',
 'yellow',
 'yellow',
 'red',
 'red',
 'red',
 'blue',
 'blue']

# %%
# Exemplo de configuração de cor e nível de tranparência dos pontos no método plt.scatter()
# Especificar c e alpha no método plt.scatter()

plt.scatter(x = gdp_cap, y = life_exp, s = np.array(pop) * 2, c =col, alpha = 0.8)

# Customizações
plt.xscale('log') 
plt.xlabel('PIB per Capita [em USD]')
plt.ylabel('Expectativa de Vida [em anos]')
plt.title('Desenvolvimento Global em 2007')
plt.xticks([1000,10000,100000], ['1k','10k','100k'])

# Mostrar o  plot
plt.show()

# %% [markdown]
# A seguir, há configuração de texto via método plt.text() no gráfico: palavras. No caso, são adicionadas as palavras "India" e "China" no gráfico.

# %%
# Scatter plot
plt.scatter(x = gdp_cap, y = life_exp, s = np.array(pop) * 2, c = col, alpha = 0.8)

# Customizações
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000,10000,100000], ['1k','10k','100k'])

# Customizações - texto nas posições relativas à China e Índia
plt.text(1550, 71, 'India')
plt.text(5700, 80, 'China')

# Adicinar grid() no gráfico
plt.grid(True)

# Mostrar
plt.show()

# %%
# Exemplo de uso do método scatter()
# Com configuração de cor, tamanho e nível de tranparência dos pontos

rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,
cmap='viridis')
plt.colorbar(); # Mostrar escala de cores

# %%
# Exemplo de uso do método scatter()
# Com configuração de cor, tamanho e nível de tranparência dos pontos
# Utilizando-se dados do beanchmark IRIS

from sklearn.datasets import load_iris

iris = load_iris()
features = iris.data.T
plt.scatter(features[0], features[1], alpha=0.2,
s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %% [markdown]
# ### Importante
# Há muitos outros tipos de gráficos no Matplot
# Por exemplo:
#     - barras
#     - errorbar
#     - boxplot
#     - pizza

# %%
# Exemplo de uso de gráficos de errorbar

import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

import numpy as np

x = np.linspace(0, 10, 50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)
plt.errorbar(x, y, yerr=dy, fmt='.k');
# Out:
# <ipython-input-19-febc90069899>:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
# Exemplo de uso de gráficos de errorbar
# com barras em cinza claro

plt.errorbar(x, y, yerr=dy, fmt='o', color='black',
ecolor='lightgray', elinewidth=3, capsize=0);

# %%
# Exemplo de Gráfico de Pizza

import seaborn as sns
import matplotlib.pyplot as plt
txtLabels = 'Cats', 'Dogs', 'Frogs', 'Others'
fractions = [45, 30, 15, 10]
offsets =(0, 0.05, 0, 0)
plt.pie(fractions, explode=offsets, labels=txtLabels,
autopct='%1.1f%%', shadow=True, startangle=90,
colors=sns.color_palette('muted') )
plt.axis('equal')
# Out:
# (-1.1014641507237515,
#  1.1308584711865424,
#  -1.142472402309424,
#  1.1020224953480677)

# %%
# Exemplos de gráficos boxplot - obtidos do site do Matplotlib

import matplotlib.pyplot as plt
import numpy as np

# fake up some data
spread = np.random.rand(50) * 100
center = np.ones(25) * 50
flier_high = np.random.rand(10) * 100 + 100
flier_low = np.random.rand(10) * -100
data = np.concatenate((spread, center, flier_high, flier_low), 0)

# basic plot
plt.boxplot(data)

# notched plot
plt.figure()
plt.boxplot(data, 1)

# change outlier point symbols
plt.figure()
plt.boxplot(data, 0, 'gD')

# don't show outlier points
plt.figure()
plt.boxplot(data, 0, '')

# horizontal boxes
plt.figure()
plt.boxplot(data, 0, 'rs', 0)

# change whisker length
plt.figure()
plt.boxplot(data, 0, 'rs', 0, 0.75)

# fake up some more data
spread = np.random.rand(50) * 100
center = np.ones(25) * 40
flier_high = np.random.rand(10) * 100 + 100
flier_low = np.random.rand(10) * -100
d2 = np.concatenate((spread, center, flier_high, flier_low), 0)
data.shape = (-1, 1)
d2.shape = (-1, 1)
# data = concatenate( (data, d2), 1 )
# Making a 2-D array only works if all the columns are the
# same length.  If they are not, then use a list instead.
# This is actually more efficient because boxplot converts
# a 2-D array into a list of vectors internally anyway.
data = [data, d2, d2[::2, 0]]
# multiple box plots on one figure
plt.figure()


plt.show()

# %% [markdown]
# ### Gráficos Tridimensionais

# %% [markdown]
# Em construção ...

# %% [markdown]
# Salvando as figuras.

# %%
# Imprimindo uma Figura

figura = plt.imread('myplot.png')
imshow(figura)
